# %%
import pandas as pd

# Load the uploaded file
df = pd.read_csv("worldpopulationdata.csv")

# Show first few rows
df.head()
# Out:
#          Series Name  Series Code    Country Name Country Code        2022  \
# 0  Population, total  SP.POP.TOTL     Afghanistan          AFG  41128771.0
# 1  Population, total  SP.POP.TOTL         Albania          ALB   2775634.0
# 2  Population, total  SP.POP.TOTL         Algeria          DZA  44903225.0
# 3  Population, total  SP.POP.TOTL  American Samoa          ASM     44273.0
# 4  Population, total  SP.POP.TOTL         Andorra          AND     79824.0
#
#          2021        2020        2019        2018        2017  ...  \
# 0  40099462.0  38972230.0  37769499.0  36686784.0  35643418.0  ...
# 1   2811666.0   2837849.0   2854191.0   2866376.0   2873457.0  ...
# 2  44177969.0  43451666.0  42705368.0  41927007.0  41136546.0  ...
# 3     45035.0     46189.0     47321.0     48424.0     49463.0  ...
# 4     79034.0     77700.0     76343.0     75013.0     73837.0  ...
#
#          2010        2009        2008        2007        2006        2005  \
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load CSV with BOM fix
df = pd.read_csv("worldpopulationdata.csv", encoding='utf-8-sig')

# Clean column names
df.columns = df.columns.str.strip()

# Quick peek at columns
print(df.columns.tolist())

# Select relevant columns: country and 2022 population
df_2022 = df[['Country Name', '2022']].dropna()

# Sort top 10 by population
top_10 = df_2022.sort_values(by='2022', ascending=False).head(10)

# Plot bar chart - Top 10 most populated countries in 2022
plt.figure(figsize=(12,6))
sns.barplot(data=top_10, x='Country Name', y='2022', palette='magma')
plt.title("Top 10 Most Populated Countries in 2022")
plt.xticks(rotation=45)
plt.ylabel("Population")
plt.xlabel("Country")
plt.tight_layout()
plt.show()

# Plot histogram of population distribution in 2022
plt.figure(figsize=(10,6))
sns.histplot(data=df_2022, x='2022', bins=30, kde=True, color='teal')
plt.title("Distribution of Country Populations in 2022")
plt.xlabel("Population")
plt.ylabel("Number of Countries")
plt.tight_layout()
plt.show()
# Out:
# ['Series Name', 'Series Code', 'Country Name', 'Country Code', '2022', '2021', '2020', '2019', '2018', '2017', '2016', '2015', '2014', '2013', '2012', '2011', '2010', '2009', '2008', '2007', '2006', '2005', '2004', '2003', '2002', '2001']
# /tmp/ipython-input-8-3186024180.py:22: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=top_10, x='Country Name', y='2022', palette='magma')
